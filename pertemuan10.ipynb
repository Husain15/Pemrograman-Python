# %% [markdown]
# <a href="https://colab.research.google.com/github/Husain15/Pemrograman-Python/blob/main/pertemuan10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
#  001.jpg
#  002.jpg
#  3scene@
#  Classroom/
# 'Colab Notebooks'/
# 'Getting started.pdf'
# 'LA_GELADI2020_1_1101180287_NUURUL ALAA HUSAIN SUBROTO.pdf'
# 'LA_GELADI2020_7_1101180287_NUURUL ALAA HUSAIN SUBROTO.pdf'
# 'LH_GELADI2020_(1)_(1101180287)_(NUURUL A`LAA HUSAIN SUBROTO).pdf'
# 'LH_GELADI2020_(2)_(1101180287)_(NUURUL A`LAA HUSAIN SUBROTO).pdf'
# 'LH_GELADI2020_(3)_(1101180287)_(NUURUL A`LAA HUSAIN SUBROTO).pdf'
# 'LH_GELADI2020_(4)_(1101180287)_(NUURUL A`LAA HUSAIN SUBROTO).pdf'
# 'LH_GELADI2020_(5)_(1101180287)_(NUURUL A`LAA HUSAIN SUBROTO) (1).pdf'
# 'LH_GELADI2020_(5)_(1101180287)_(NUURUL A`LAA HUSAIN SUBROTO).pdf'
# 'LH_GELADI2020_(6)_(1101180287)_(NUURUL A`LAA HUSAIN SUBROTO).pdf'
# 'runmod 1.png'
# 'Tubes Kelompok G.rar'
#  UTSKUpdf.pdf
# 'video demo.mp4'
# 'Video Presentasi Geladi 1101180287 Nuurul Alaa Husain Subroto-1.m4v'

# %%
# import the necessary packages

from keras.models import Sequential
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense 
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths 
import numpy as np
import os

# %%
#grab all image paths in the input dataset directory, then initialize

# our list of images and corresponding class labels 
print("[INFO] loading images...")
imagePaths = paths.list_images("3scene")
data = []
labels = []
# Out:
# [INFO] loading images...

# %%
# loop over our input images

for imagePath in imagePaths:
  # load the input image from disk, resize it to 64x64 pixels, scale 
  # the pixel intensities to the range [0, 1], and then update our
  # images list
  image = Image.open(imagePath)
  image = np.array(image.resize((64, 64))) / 255.0
  data.append(image)

  # extract the class label from the file path and update the
  # labels list
  label = imagePath.split(os.path. sep)[-2] 
  labels.append(label)

# %%
print(labels)
# Out:
# ['forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'forest', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', 'coast', ...

# %%
# encode the labels, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
print(labels)
# Out:
# [[0 1 0]
#  [0 1 0]
#  [0 1 0]
#  ...
#  [0 0 1]
#  [0 0 1]
#  [0 0 1]]

# %%
# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),	np.array(labels), test_size=0.25, shuffle=True)
print(trainX.shape)
print(testX.shape)
# Out:
# (711, 64, 64, 3)
# (237, 64, 64, 3)

# %%
from keras.models import Sequential
from keras.layers.core import Flatten
from keras.layers.core import Dense

model = Sequential(
    [
        Flatten(input_shape=(64*64*3,)),
        Dense(100, activation="relu", name="layer1"),
        Dense(16, activation="relu", name="layer2"),
        Dense(16, activation="relu", name="layer3"),
        Dense(3, activation = "softmax", name="layer4"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 12288)             0
# _________________________________________________________________
# layer1 (Dense)               (None, 100)               1228900
# _________________________________________________________________
# layer2 (Dense)               (None, 16)                1616
# _________________________________________________________________
# layer3 (Dense)               (None, 16)                272
# _________________________________________________________________
# layer4 (Dense)               (None, 3)                 51
# =================================================================
# Total params: 1,230,839
# Trainable params: 1,230,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=25, batch_size=32)
# Out:
# [INFO] training network...
# Epoch 1/25
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_2_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_2_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 20/23 [=========================>....] - ETA: 0s - loss: 1.1434 - accuracy: 0.4688WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_2_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - 0s 18ms/step - loss: 1.1119 - accuracy: 0.4824 - val_loss: 0.9043 - val_accuracy: 0.5232
# Epoch 2/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8345 - accuracy: 0.6428 - val_loss: 1.3174 - val_accuracy: 0.5316
# Epoch 3/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7467 - accuracy: 0.7145 - val_loss: 0.6147 - val_accuracy: 0.8017
# Epoch 4/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6960 - accuracy: 0.7328 - val_loss: 0.6043 - val_accuracy: 0.7637
# Epoch 5/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7760 - accuracy: 0.6751 - val_loss: 0.5727 - val_accuracy: 0.7764
# Epoch 6/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6846 - accuracy: 0.7440 - val_loss: 0.5842 - val_accuracy: 0.7342
# Epoch 7/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5949 - accuracy: 0.7736 - val_loss: 0.5823 - val_accuracy: 0.7806
# Epoch 8/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6762 - accuracy: 0.7229 - val_loss: 0.5124 - val_accuracy: 0.8186
# Epoch 9/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5351 - accuracy: 0.8129 - val_loss: 0.5059 - val_accuracy: 0.8143
# Epoch 10/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4992 - accuracy: 0.8228 - val_loss: 0.5038 - val_accuracy: 0.8186
# Epoch 11/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5033 - accuracy: 0.8256 - val_loss: 0.5996 - val_accuracy: 0.7342
# Epoch 12/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4946 - accuracy: 0.8158 - val_loss: 0.5794 - val_accuracy: 0.7764
# Epoch 13/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4538 - accuracy: 0.8439 - val_loss: 0.5422 - val_accuracy: 0.7806
# Epoch 14/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4776 - accuracy: 0.8270 - val_loss: 0.5797 - val_accuracy: 0.7890
# Epoch 15/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6664 - accuracy: 0.7257 - val_loss: 0.6129 - val_accuracy: 0.7595
# Epoch 16/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.6015 - accuracy: 0.7722 - val_loss: 0.6267 - val_accuracy: 0.7426
# Epoch 17/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4668 - accuracy: 0.8242 - val_loss: 0.4955 - val_accuracy: 0.8017
# Epoch 18/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4217 - accuracy: 0.8467 - val_loss: 0.5213 - val_accuracy: 0.8059
# Epoch 19/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4044 - accuracy: 0.8509 - val_loss: 0.6405 - val_accuracy: 0.7679
# Epoch 20/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4380 - accuracy: 0.8397 - val_loss: 0.5473 - val_accuracy: 0.8059
# Epoch 21/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3465 - accuracy: 0.8847 - val_loss: 0.4398 - val_accuracy: 0.8186
# Epoch 22/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3367 - accuracy: 0.8776 - val_loss: 0.4615 - val_accuracy: 0.8397
# Epoch 23/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3080 - accuracy: 0.8917 - val_loss: 0.4977 - val_accuracy: 0.8017
# Epoch 24/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3283 - accuracy: 0.8805 - val_loss: 0.4439 - val_accuracy: 0.8523
# Epoch 25/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3616 - accuracy: 0.8650 - val_loss: 0.5314 - val_accuracy: 0.8439

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_2_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.83      0.86      0.85        87
#       forest       0.84      0.93      0.88        87
#      highway       0.88      0.70      0.78        63
#
#     accuracy                           0.84       237
#    macro avg       0.85      0.83      0.84       237
# weighted avg       0.85      0.84      0.84       237

# %%
model.save('nnmodel_scene')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: nnmodel_scene/assets

# %%
import cv2
import matplotlib.pyplot as plt
image1='coast_test.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()

# %%
image_testing = Image.open ('coast_test.jpg')
image_testing = np.array(image_testing.resize((64,64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 64, 64, 3)

# %%
output = model.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_2_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (1, 64, 64, 3).
# [[9.919755e-01 9.598897e-07 8.023614e-03]]
# ['coast']
